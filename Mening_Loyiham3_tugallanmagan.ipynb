# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
# Out:
#     Yillar_Years  Acute_intestinal_infections  Bacterial_dysentery  \
# 0           2000                         44.6                  4.9
# 1           2001                         42.4                  4.8
# 2           2002                         40.0                  4.8
# 3           2003                         34.2                  3.9
# 4           2004                         33.2                  3.5
# 5           2005                         36.6                  3.8
# 6           2006                         35.5                  3.4
# 7           2007                         32.5                  3.1
# 8           2008                         33.4                  2.9
# 9           2009                         32.7                  2.6
# 10          2010                         33.8                  2.9
# 11          2011                         31.8                  2.7
# 12          2012                         33.2                  2.3
# 13          2013                         35.1                  2.2
# 14          2014                         38.2                  1.9
# 15          2015                         39.0                  2.1
# 16          2016                         37.5                  1.6
# 17          2017                         44.6                  1.7
# 18          2018                         31.8                  1.4
# 19          2019                         39.0                  1.5
# 20          2020                         18.9                  0.3
# 21          2021                         31.6                  0.7
#
#     Salmonella Typhoid_fever  Influenza  Viral_hepatatis  Scarlet fever  \
# 0          1.5           204     1035.3             57.8            0.5
# 1          1.3           219      858.3             40.2            0.7
# 2          1.5           0.1      802.1             33.4            0.9
# 3          1.3           0.1      769.9             29.4            0.9
# 4          1.2           104      679.8             37.7            0.8
# 5          1.4           120      594.8             30.3            0.9
# 6          1.6            79      560.2             29.9            0.9
# 7          1.7            55      547.3             34.0            0.6
# 8          1.4            54      513.4             32.2            0.4
# 9          1.1            51      515.3             37.5            0.4
# 10         1.3            52      332.5             36.4            0.5
# 11         0.9            49      312.8             32.6            0.6
# 12         0.8            51      340.4             29.5            0.5
# 13         0.7            76      381.0             41.7            0.4
# 14         0.8            22      372.1             37.9            0.4
# 15         0.5            16      368.0             25.8            0.5
# 16         0.7            11      436.3             38.1            0.5
# 17         0.7             5      410.3             32.1            0.7
# 18         0.9             9      437.9             31.0            1.7
# 19         1.1             2      510.8             27.3            0.2
# 20         0.4             1      432.5             11.5            1.0
# 21         0.5             -      525.7              7.9            0.9
#
#     Pertussis Maesles  Meningococcal_infection  Brucellosis
# 0          72      73                      105          503
# 1          59      21                      250          482
# 2          79      26                      111          410
# 3          40      85                       65          563
# 4          35      71                       65          485
# 5         126     737                       61          564
# 6         115     856                       78          468
# 7         106     863                       56          376
# 8          31       1                       34          410
# 9          35       -                       26          332
# 10         33     117                       25          454
# 11         36     457                       11          422
# 12         62       -                        9          362
# 13         42       -                       10          572
# 14         65       5                       10          702
# 15         84       5                       17          874
# 16        101       -                        7          844
# 17        102       -                        9          858
# 18        119      22                        6          778
# 19        106    11.3                      149          745
# 20         39     4.3                        7          418
# 21          2       -                        7          548

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
df = pd.DataFrame(kasallanish)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
  
plt.bar(X, Y, color='b')
plt.title("O'zbekiston aholisining o'tkir ichak infeksiyalari bilan kasallanishi darajasi")
plt.xlabel("Yillar")
plt.ylabel("O'tkir ichak infeksiyalari, ming")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
df = pd.DataFrame(kasallanish)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 2])
  
plt.plot(X, Y, color='g')
plt.title("O'zbekiston aholisining bakterial dizenteriya bilan kasallanishi darajasi")
plt.xlabel("Yillar")
plt.ylabel("Bakterial dizenteriya, ming")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
kasallanish = pd.read_csv ('Aholining_kasallanishi.csv')
kasallanish
df = pd.DataFrame(kasallanish)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 3])
  
plt.step(X, Y, color='r')
plt.title("O'zbekiston aholisining salmonellez bilan kasallanishi darajasi")
plt.xlabel("Yillar")
plt.ylabel("Salmonellez, ming")
  
plt.show()

# %%
sskorsatkich = pd.read_csv ('SS_korsatkichlari.csv')
sskorsatkich
# Out:
#     Yillar_Years  Hospital_beds  Beds_pregnant  Capacity_clinics  \
# 0           2000           55.9           40.5             157.7
# 1           2001           55.8           39.6             160.4
# 2           2002           57.8           37.6             163.1
# 3           2003           57.4           35.7             159.2
# 4           2004           54.9           32.0             155.2
# 5           2005           54.1           31.0             152.7
# 6           2006           53.9           29.1             153.2
# 7           2007           51.3           26.9             153.1
# 8           2008           49.9           25.9             150.2
# 9           2009           49.8           25.3             148.4
# 10          2010           47.9           24.0             145.1
# 11          2011           47.3           23.4             143.4
# 12          2012           46.1           22.7             141.5
# 13          2013           43.9           21.8             137.3
# 14          2014           42.2           20.9             131.1
# 15          2015           41.1           20.2             128.9
# 16          2016           41.1           19.9             128.2
# 17          2017           41.6           20.9             124.1
# 18          2018           46.6           19.6             133.7
# 19          2019           45.2           19.3             149.5
# 20          2020           46.6           19.1             197.5
# 21          2021           46.6           19.6             130.8
#
#     Number_doctors  Number_nurses
# 0             32.8          104.7
# 1             32.4          104.7
# 2             31.9          104.6
# 3             31.4          103.8
# 4             29.9          102.2
# 5             29.1          103.0
# 6             28.4          102.9
# 7             28.4          104.8
# 8             28.0          105.8
# 9             29.0          107.8
# 10            27.4          106.5
# 11            27.7          108.2
# 12            27.1          108.2
# 13            26.8          107.4
# 14            26.4          107.2
# 15            26.4          106.5
# 16            26.2          106.3
# 17            26.1          106.6
# 18            27.2          108.2
# 19            27.1          107.8
# 20            27.0          107.0
# 21            27.1          105.6

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
sskorsatkich = pd.read_csv ('SS_korsatkichlari.csv')

df = pd.DataFrame(sskorsatkich)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
  
plt.scatter(X, Y, color='y')
plt.title("Sogliqni saqlash korsatkichlari")
plt.xlabel("Yillar")
plt.ylabel("10 000 aholiga shifoxona orinlari soni")
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
sskorsatkich = pd.read_csv ('SS_korsatkichlari.csv')

df = pd.DataFrame(sskorsatkich)
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 4])
  
plt.fill(X, Y, color='grey')
plt.title("Sogliqni saqlash korsatkichlari")
plt.xlabel("Yillar")
plt.ylabel("10 000 aholiga shifokorlar soni")
  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

df = pd.read_csv('SS_korsatkichlari.csv')

fig, ax = plt.subplots(figsize=(15,4), nrows=1, ncols=3);
fig, ax = plt.subplots(figsize=(15,4), nrows=1, ncols=3);
ax[0].hist(df['Hospital_beds'])
ax[0].set_title('Hospital beds')
ax[1].hist(df['Beds_pregnant'])
ax[1].set_title('Beds pregnant')
ax[2].hist(df['Capacity_clinics'])
ax[2].set_title('Capacity clinics');

# %%
plt.figure(figsize = (18,6));
ax1 = plt.subplot(1, 3, 1)
df['Hospital_beds'].hist()
plt.title('Hospital beds')
ax2 = plt.subplot(1, 3, 2)
df['Beds_pregnant'].hist();
plt.title('Beds pregnant')
ax3 = plt.subplot(1, 3, 3)
df['Capacity_clinics'].hist()
plt.title('Capacity clinics')
# Out:
# Text(0.5, 1.0, 'Capacity clinics')
